# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
netflix = pd.read_csv('netflix_titles.csv')

# %%
# Reload Data and print shape
netflix.shape

print("The number of Rows is : ", netflix.shape[0])
print("The number of Columns is : ", netflix.shape[1])
# Out:
# The number of Rows is :  8807
# The number of Columns is :  12

# %%
# Display random answer
# observations: multiple answer need to be splitted
# Reference to the schema needed to understand
netflix.sample(1).iloc[0]
# Out:
# show_id                                                     s4475
# type                                                        Movie
# title                                                Santo Cachón
# director                                                      NaN
# cast                                                          NaN
# country                                                  Colombia
# date_added                                       October 26, 2018
# release_year                                                 2018
# rating                                                      TV-14
# duration                                                   87 min
# listed_in         Comedies, International Movies, Romantic Movies
# description     A man whose wife is repeatedly cheating on him...
# Name: 4474, dtype: object

# %%
# print the General information of the data
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
# Get stats for the numerical column
netflix.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
# Showing the first 5 Rows
netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# ### 1. Is there any duplicated record in this dataset ? if yes, then remove the duplicated record.

# %%
# to check row wise and detect the duplicated rows
netflix[netflix.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# ### 2. Is there any null value present in any column? show with heat map

# %%
# to show where null data is present
netflix.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
# to show the count of null values in each column
netflix.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
# using heat map to show null values count
sns.heatmap(netflix.isnull())
# Out:
# <Axes: >

# %% [markdown]
# #### Q1. In which year highest number of TV shows & Movies were released ? Showing with bar Graph

# %%
netflix.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
netflix['release_year'].value_counts()
# Out:
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
#         ...
# 1959       1
# 1925       1
# 1961       1
# 1947       1
# 1966       1
# Name: release_year, Length: 74, dtype: int64

# %%
netflix['release_year'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# #### Q2. How many Movies & TV shows are in the dataset ? showing with bar graph

# %%
netflix.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
# To group all unique times of a column and show their count
netflix.groupby('type').type.count()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
# To show the count of all unique values of any column in the face of bar graph
netflix.groupby('type').type.count().plot(kind='bar')
# Out:
# <Axes: xlabel='type'>

# %% [markdown]
# #### Q3. show all the movies that were released in year 2000.

# %%
netflix[(netflix['type'] == 'Movie') & (netflix['release_year'] == 2000)]
# Out:
#      show_id   type                                              title  \
# 180     s181  Movie                 The Nutty Professor II: The Klumps
# 350     s351  Movie                                      Space Cowboys
# 359     s360  Movie                       The Original Kings of Comedy
# 566     s567  Movie                                   Charlie's Angels
# 593     s594  Movie                                           Snow Day
# 779     s780  Movie                                  Battlefield Earth
# 952     s953  Movie                               The Whole Nine Yards
# 3472   s3473  Movie                        Rugrats in Paris: The Movie
# 4545   s4546  Movie             Monty Python: Before the Flying Circus
# 4723   s4724  Movie                                               Fiza
# 4956   s4957  Movie                        Phir Bhi Dil Hai Hindustani
# 5953   s5954  Movie                             Joseph: King of Dreams
# ...

# %% [markdown]
# #### Q4. Show only the title of all tv shows that were released in United States only.

# %%
netflix[(netflix['type'] == 'Movie') & (netflix['country'] == 'United States')]['title']
# Out:
# 0       Dick Johnson Is Dead
# 9               The Starling
# 27                 Grown Ups
# 28                Dark Skies
# 41                      Jaws
#                 ...
# 8791             Young Adult
# 8793    Yours, Mine and Ours
# 8802                  Zodiac
# 8804              Zombieland
# 8805                    Zoom
# Name: title, Length: 2058, dtype: object

# %% [markdown]
# #### Q4. Show top 10 Directors, who gave the highest number of TV Shows & Movies to Netflix ?

# %%
netflix['director'].value_counts().head(10)
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: director, dtype: int64

# %% [markdown]
# #### Q5. Show all the records, where "Category is movie and listed_in is Documentaries" or "Country is United Kingdom"

# %%
netflix.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
netflix[(netflix['type'] == 'Movie') & (netflix['listed_in'] == 'Documentaries')]
# Out:
#      show_id   type                                        title  \
# 0         s1  Movie                         Dick Johnson Is Dead
# 45       s46  Movie                       My Heroes Were Cowboys
# 117     s118  Movie                                Final Account
# 221     s222  Movie  Bob Ross: Happy Accidents, Betrayal & Greed
# 304     s305  Movie          Lady Boss: The Jackie Collins Story
# ...      ...    ...                                          ...
# 8723   s8724  Movie                     What Makes a Psychopath?
# 8737   s8738  Movie                   Why Are We Getting So Fat?
# 8738   s8739  Movie                                     Why Knot
# 8739   s8740  Movie           Why We Fight: The Battle of Russia
# 8763   s8764  Movie              WWII: Report from the Aleutians
#
#                                     director            cast  \
# 0                            Kirsten Johnson             NaN
# ...

# %%
netflix[(netflix['type'] == 'Movie') & (netflix['listed_in'] == 'Documentaries') | (netflix['country'] == 'United Kingdom')]
# Out:
#      show_id     type                            title         director  \
# 0         s1    Movie             Dick Johnson Is Dead  Kirsten Johnson
# 8         s9  TV Show    The Great British Baking Show  Andy Devonshire
# 32       s33  TV Show                    Sex Education              NaN
# 45       s46    Movie           My Heroes Were Cowboys      Tyler Greco
# 65       s66  TV Show                     Numberblocks              NaN
# ...      ...      ...                              ...              ...
# 8741   s8742  TV Show                      Wild Arabia              NaN
# 8744   s8745    Movie                         Williams  Morgan Matthews
# 8758   s8759  TV Show           World's Busiest Cities              NaN
# 8763   s8764    Movie  WWII: Report from the Aleutians      John Huston
# 8786   s8787    Movie                     You Can Tutu      James Brown
#
#                                                    cast         country  \
# ...

# %% [markdown]
# #### Q8. In how many movies/shows, Tom Cruise was cast?

# %%
netflix.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
netflix[netflix['cast'] == 'Tom Cruise']
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
# using str.contains()

netflix[netflix['cast'].str.contains('Tom Cruise')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 3
#       1 # using str.contains()
# ----> 3 netflix[netflix['cast'].str.contains('Tom Cruise')]
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3797, in DataFrame.__getitem__(self, key)
#    3794     return self.where(key)
#    3796 # Do we have a (boolean) 1d indexer?
# -> 3797 if com.is_bool_indexer(key):
#    3798     return self._getitem_bool_array(key)
#    3800 # We are left with two options: a single key, and a collection of keys,
#    3801 # We interpret tuples as collections only for non-MultiIndex
#
# File ~\anaconda3\lib\site-packages\pandas\core\common.py:135, in is_bool_indexer(key)
#     131     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     132     if lib.infer_dtype(key_array) == "boolean" and isna(key_array).any():
# ...

# %% [markdown]
# #### Creating new data frame

# %%
# Droping the row that contains all or any missing values

netflix_new = netflix.dropna()

# %%
netflix_new.head(2)
# Out:
#   show_id     type                          title         director  \
# 7      s8    Movie                        Sankofa     Haile Gerima
# 8      s9  TV Show  The Great British Baking Show  Andy Devonshire
#
#                                                 cast  \
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
#
#                                              country          date_added  \
# 7  United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 8                                     United Kingdom  September 24, 2021
#
#    release_year rating   duration  \
# 7          1993  TV-MA    125 min
# 8          2021  TV-14  9 Seasons
#
#                                           listed_in  \
# 7  Dramas, Independent Movies, International Movies
# 8                      British TV Shows, Reality TV
#
#                                          description
# ...

# %%
netflix_new[netflix_new['cast'].str.contains('Tom Cruise')]
# Out:
#      show_id   type     title              director  \
# 341     s342  Movie  Magnolia  Paul Thomas Anderson
# 1254   s1255  Movie  Rain Man        Barry Levinson
#
#                                                    cast        country  \
# 341   John C. Reilly, Philip Baker Hall, Tom Cruise,...  United States
# 1254  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#           date_added  release_year rating duration  \
# 341   August 1, 2021          1999      R  189 min
# 1254   March 1, 2021          1988      R  134 min
#
#                        listed_in  \
# 341   Dramas, Independent Movies
# 1254      Classic Movies, Dramas
#
#                                             description
# 341   Through chance, history and divine interventio...
# 1254  Motivated by money, a selfish workaholic seeki...

# %% [markdown]
# #### Q9. what are the diffrent rating definde by Netflix ?

# %%
netflix['rating'].nunique()
# Out:
# 17

# %%
netflix['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# #### Q9. How many Movie got the "R" rating, after year 2018 ?

# %%
netflix[(netflix['type'] == 'Movie') & (netflix['rating'] == 'R')]
# Out:
#      show_id   type                        title  \
# 46       s47  Movie                   Safe House
# 48       s49  Movie                 Training Day
# 81       s82  Movie                         Kate
# 122     s123  Movie                   In the Cut
# 131     s132  Movie  Blade Runner: The Final Cut
# ...      ...    ...                          ...
# 8765   s8766  Movie                           XX
# 8768   s8769  Movie            Y Tu Mamá También
# 8791   s8792  Movie                  Young Adult
# 8802   s8803  Movie                       Zodiac
# 8804   s8805  Movie                   Zombieland
#
#                                                director  \
# 46                                      Daniel Espinosa
# 48                                        Antoine Fuqua
# 81                                Cedric Nicolas-Troyan
# 122                                        Jane Campion
# 131                                        Ridley Scott
# ...

# %%
netflix[(netflix['type'] == 'Movie') & (netflix['rating']=='R') & (netflix['release_year'] > 2018)]
# Out:
#      show_id   type                        title               director  \
# 81       s82  Movie                         Kate  Cedric Nicolas-Troyan
# 214     s215  Movie  SAS: Rise of the Black Swan         Magnus Martens
# 247     s248  Movie                   Sweet Girl   Brian Andrew Mendoza
# 363     s364  Movie                    The Vault        Jaume Balagueró
# 437     s438  Movie                   Cosmic Sin           Edward Drake
# ...      ...    ...                          ...                    ...
# 6286   s6287  Movie           Berlin, I Love You                    NaN
# 6623   s6624  Movie                       Domino         Brian De Palma
# 6682   s6683  Movie            Elizabeth Harvest    Sebastian Gutierrez
# 6713   s6714  Movie              Everybody Knows         Asghar Farhadi
# 7950   s7951  Movie                   Saving Zoë        Jeffrey G. Hunt
#
#                                                    cast  \
# ...

# %% [markdown]
# #### Q10. What is the maximum duration of a MOvie/Show on Netflix ?

# %%
netflix.duration.unique()
# Out:
# array(['90 min', '2 Seasons', '1 Season', '91 min', '125 min',
#        '9 Seasons', '104 min', '127 min', '4 Seasons', '67 min', '94 min',
#        '5 Seasons', '161 min', '61 min', '166 min', '147 min', '103 min',
#        '97 min', '106 min', '111 min', '3 Seasons', '110 min', '105 min',
#        '96 min', '124 min', '116 min', '98 min', '23 min', '115 min',
#        '122 min', '99 min', '88 min', '100 min', '6 Seasons', '102 min',
#        '93 min', '95 min', '85 min', '83 min', '113 min', '13 min',
#        '182 min', '48 min', '145 min', '87 min', '92 min', '80 min',
#        '117 min', '128 min', '119 min', '143 min', '114 min', '118 min',
#        '108 min', '63 min', '121 min', '142 min', '154 min', '120 min',
#        '82 min', '109 min', '101 min', '86 min', '229 min', '76 min',
#        '89 min', '156 min', '112 min', '107 min', '129 min', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '70 min', '84 min',
# ...

# %%
netflix.duration.dtypes
# Out:
# dtype('O')

# %%
netflix[['Minutes','Unit']] = netflix['duration'].str.split(' ', expand = True)

# %%
netflix.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description Minutes     Unit
# 0  As her father nears the end of his life, filmm...      90      min
# 1  After crossing paths at a party, a Cape Town t...       2  Seasons

# %%
netflix['Minutes'].fillna(0, inplace = True)

# %%
netflix.groupby('Minutes')['duration'].value_counts().sort_values(ascending = False).head()
# Out:
# Minutes  duration
# 1        1 Season     1793
# 2        2 Seasons     425
# 3        3 Seasons     199
# 90       90 min        152
# 93       93 min        146
# Name: duration, dtype: int64

# %% [markdown]
# #### Q11. Which Individual country has the Highest no. of TV Shows ?

# %%
netflix.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description Minutes     Unit
# 0  As her father nears the end of his life, filmm...      90      min
# 1  After crossing paths at a party, a Cape Town t...       2  Seasons

# %%
netflix_tvshow = netflix[netflix['type'] == 'TV Show']

# %%
netflix_tvshow.head(2)
# Out:
#   show_id     type          title         director  \
# 1      s2  TV Show  Blood & Water              NaN
# 2      s3  TV Show      Ganglands  Julien Leclercq
#
#                                                 cast       country  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
#
#            date_added  release_year rating   duration  \
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description Minutes     Unit
# 1  After crossing paths at a party, a Cape Town t...       2  Seasons
# 2  To protect his family from a powerful drug lor...       1   Season

# %%
netflix_tvshow.country.value_counts().head(1)
# Out:
# United States    760
# Name: country, dtype: int64

# %% [markdown]
# #### Q12. How can we sort the dataset by year ?

# %%
netflix.sort_values(by = 'release_year')
# Out:
#      show_id     type                                          title  \
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*
# 7790   s7791    Movie                                 Prelude to War
# 8205   s8206    Movie                           The Battle of Midway
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
# 8739   s8740    Movie             Why We Fight: The Battle of Russia
# ...      ...      ...                                            ...
# 862     s863  TV Show                                        Special
# 861     s862    Movie             Little Singham Future mein Satakli
# 857     s858  TV Show                                   The Neighbor
# 876     s877  TV Show                                   Alma Matters
# 965     s966  TV Show                                         Yasuke
#
#                          director  \
# 4250                          NaN
# 7790                  Frank Capra
# ...

# %%
netflix.sort_values(by = 'release_year', ascending = True)
# Out:
#      show_id     type                                          title  \
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*
# 7790   s7791    Movie                                 Prelude to War
# 8205   s8206    Movie                           The Battle of Midway
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
# 8739   s8740    Movie             Why We Fight: The Battle of Russia
# ...      ...      ...                                            ...
# 862     s863  TV Show                                        Special
# 861     s862    Movie             Little Singham Future mein Satakli
# 857     s858  TV Show                                   The Neighbor
# 876     s877  TV Show                                   Alma Matters
# 965     s966  TV Show                                         Yasuke
#
#                          director  \
# 4250                          NaN
# 7790                  Frank Capra
# ...

# %% [markdown]
# ### Q13. Find all the instances where :
#
# #### Type is 'Movies' and listed_in 'Dramas'
#
# #### or
#
# #### Type is 'TV Show' and listed_in 'Kids'TV

# %%
netflix[(netflix['type'] == 'Movie') & (netflix['listed_in'] == 'Dramas')].head()
# Out:
#     show_id   type                title             director  \
# 112    s113  Movie                Worth       Sara Colangelo
# 129    s130  Movie   An Unfinished Life      Lasse Hallström
# 142    s143  Movie      Freedom Writers  Richard LaGravenese
# 162    s163  Movie             Marshall      Reginald Hudlin
# 329    s330  Movie  Catch Me If You Can     Steven Spielberg
#
#                                                   cast  \
# 112  Michael Keaton, Stanley Tucci, Amy Ryan, Shuno...
# 129  Robert Redford, Jennifer Lopez, Morgan Freeman...
# 142  Hilary Swank, Patrick Dempsey, Scott Glenn, Im...
# 162  Chadwick Boseman, Josh Gad, Kate Hudson, Sterl...
# 329  Leonardo DiCaprio, Tom Hanks, Christopher Walk...
#
#                              country         date_added  release_year rating  \
# 112                              NaN  September 3, 2021          2021  PG-13
# 129           Germany, United States  September 1, 2021          2005  PG-13
# ...

# %%
netflix[(netflix['type'] == 'TV Show') & (netflix['listed_in'] == "Kids' TV")].head()
# Out:
#     show_id     type                    title director  \
# 34      s35  TV Show  Tayo and Little Wizards      NaN
# 39      s40  TV Show             Chhota Bheem      NaN
# 65      s66  TV Show             Numberblocks      NaN
# 89      s90  TV Show              Mighty Raju      NaN
# 100    s101  TV Show  Tobot Galaxy Detectives      NaN
#
#                                                   cast         country  \
# 34   Dami Lee, Jason Lee, Bommie Catherine Han, Jen...             NaN
# 39   Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...           India
# 65   Beth Chalmers, David Holt, Marcel McCalla, Ter...  United Kingdom
# 89   Julie Tejwani, Sabina Malik, Jigna Bhardwaj, R...             NaN
# 100  Austin Abell, Travis Turner, Cole Howard, Anna...             NaN
#
#              date_added  release_year rating   duration listed_in  \
# 34   September 17, 2021          2020  TV-Y7   1 Season  Kids' TV
# 39   September 16, 2021          2021  TV-Y7  3 Seasons  Kids' TV
# ...

# %%
# Combine the first condition and the second condition

netflix[(netflix['type'] == 'Movie') & (netflix['listed_in'] == 'Dramas') | (netflix['type'] == 'TV Show') & (netflix['listed_in'] == "Kids' TV")]
# Out:
#      show_id     type                    title          director  \
# 34       s35  TV Show  Tayo and Little Wizards               NaN
# 39       s40  TV Show             Chhota Bheem               NaN
# 65       s66  TV Show             Numberblocks               NaN
# 89       s90  TV Show              Mighty Raju               NaN
# 100     s101  TV Show  Tobot Galaxy Detectives               NaN
# ...      ...      ...                      ...               ...
# 8691   s8692    Movie                Wakefield     Robin Swicord
# 8696   s8697    Movie                War Horse  Steven Spielberg
# 8783   s8784  TV Show                     Yoko               NaN
# 8785   s8786  TV Show                      YOM               NaN
# 8797   s8798  TV Show                Zak Storm               NaN
#
#                                                    cast  \
# 34    Dami Lee, Jason Lee, Bommie Catherine Han, Jen...
# 39    Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...
# ...
